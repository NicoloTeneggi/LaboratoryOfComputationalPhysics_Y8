# %% [markdown]
# 1\. **Maximum wind speed prediction at the Sprogø station**
#
# The exercise goal is to predict the maximum wind speed occurring every 50 years even if no measure exists for such a period. The available data are only measured over 21 years at the Sprogø meteorological station located in Denmark.
#
# The annual maxima are supposed to fit a normal probability density function. However such function is not going to be estimated because it gives a probability from a wind speed maxima. Finding the maximum wind speed occurring every 50 years requires the opposite approach, the result needs to be found from a defined probability. That is the quantile function role and the exercise goal will be to find it. In the current model, it is supposed that the maximum wind speed occurring every 50 years is defined as the upper 2% quantile.
#
# By definition, the quantile function is the inverse of the cumulative distribution function. The latter describes the probability distribution of an annual maxima. In the exercise, the cumulative probability $p_i$ for a given year i is defined as $p_i = i/(N+1)$ with $N = 21$, the number of measured years. Thus it will be possible to calculate the cumulative probability of every measured wind speed maxima. From those experimental points, the scipy.interpolate module will be very useful for fitting the quantile function. Finally the 50 years maxima is going to be evaluated from the cumulative probability of the 2% quantile.
#
# Practically, load the dataset:
#
# ```python
# import numpy as np
# max_speeds = np.load('max-speeds.npy')
# years_nb = max_speeds.shape[0]
# ```
#
# Compute then the cumulative probability $p_i$ (`cprob`) and sort the maximum speeds from the data. Use then the  UnivariateSpline from scipy.interpolate to define a quantile function and thus estimate the probabilities.
#
# In the current model, the maximum wind speed occurring every 50 years is defined as the upper 2% quantile. As a result, the cumulative probability value will be:
#
# ```python
# fifty_prob = 1. - 0.02
# ```
#
# So the storm wind speed occurring every 50 years can be guessed as:
#
# ``` python
# fifty_wind = quantile_func(fifty_prob)
# ```

# %%
import numpy as np
import pandas as pd
import scipy.interpolate as si
import matplotlib.pyplot as plt

max_speeds = np.load('max-speeds.npy')
years_nb = max_speeds.shape[0]

cprob = [i / (years_nb + 1) for i in range(1, years_nb + 1)]
max_speeds = np.sort(max_speeds)

spl1 = si.UnivariateSpline(max_speeds, cprob, k = 4)
x1 = np.linspace(max_speeds.min(), max_speeds.max(), 1000)

quant = si.UnivariateSpline(cprob, max_speeds, k = 4)
x2 = np.linspace(0, 1, 1000)

fifty_prob = 1. - 0.02
fifty_wind = quant(fifty_prob)

print(f'The maximum predicted wind speed over 50 years is {fifty_wind:.2f}')



## PLOTTING
fig, ax = plt.subplots(1, 2, figsize = (12, 4))
ax[0].scatter(max_speeds, cprob, color = 'xkcd:dark blue green', zorder = 3)
ax[0].plot(x1, spl1(x1), zorder = 3, color = 'xkcd:crimson')
ax[0].grid()
ax[0].set_title('CDF')

ax[1].scatter(cprob, max_speeds, color = 'xkcd:dark blue green', zorder = 3)
ax[1].plot(x2, quant(x2), color = 'xkcd:crimson', zorder = 3)
ax[1].grid()
ax[1].set_title('Quantile Function')
# Out:
# The maximum predicted wind speed over 50 years is 33.99
# Text(0.5, 1.0, 'Quantile Function')

# %% [markdown]
# 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18
#
# min: -62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58
#
# * Plot these temperature extremes.
# * Define a function that can describe min and max temperatures.
# * Fit this function to the data with scipy.optimize.curve_fit().
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
import scipy as sc

max = [17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18]
min = [-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
x = np.arange(12)

def fun(x, mu, sigma, off, amp):
    return sc.stats.norm.pdf(x, loc = mu, scale = sigma)* amp + off

par, cov = sc.optimize.curve_fit(fun, x, max)
par2, cov2 = sc.optimize.curve_fit(fun, x, min, p0 = [6, 3, -62, 50])

print(f'Time offset for maxima fit: {par[0]:.2f} +- {np.sqrt(cov[0, 0]):.2f}')
print(f'Time offset for minima fit: {par2[0]:.2f} +- {np.sqrt(cov2[0, 0]):.2f}')
# Out:
# Time offset for maxima fit: 5.74 +- 0.08
# Time offset for minima fit: 6.16 +- 0.05

# %%
#PLOTTING

fig, ax = plt.subplots(1, 2, figsize = (12, 4))
ax[0].scatter(x, max, zorder = 3, color ='xkcd:ultramarine blue', label = 'Exp values')
ax[1].scatter(x, min, zorder = 3, color ='xkcd:ultramarine blue', label = 'Exp values')
ax[0].set_xticks(np.arange(12))
ax[0].set_xticklabels(months)
ax[1].set_xticks(np.arange(12))
ax[1].set_xticklabels(months)
ax[0].grid()
ax[1].grid()
ax[0].set_title('Maximum Temperatures')
ax[1].set_title('Minimum Temperatures')


xx = np.linspace(0, 11, 1000)
ax[0].plot(xx, fun(xx, *par), color = 'xkcd:twilight blue', label = 'Gaussian fit')
ax[1].plot(xx, fun(xx, *par2), color = 'xkcd:twilight blue', label = 'Gaussian fit')
ax[0].legend(loc = 'best')
ax[1].legend(loc = 'best')

# %% [markdown]
# 3\. **2D minimization of a six-hump camelback function**
#
# $$
# f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2
# $$
#
# has multiple global and local minima. Find the global minima of this function.
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use numpy.meshgrid() and pylab.imshow() to find visually the regions.
# * Use scipy.optimize.minimize(), optionally trying out several of its methods.
#
# How many global minima are there, and what is the function value at those points? What happens for an initial guess of $(x, y) = (0, 0)$ ?

# %%
import matplotlib as mpl

def f(x, y):
    return (4 - 2.1 * x**2 + x**4 / 3) * x**2 + x*y + (4*y**2 - 4) * y**2

x, y = np.meshgrid(np.linspace(-2, 2, 1000), np.linspace(-1, 1, 1000))

Z = f(x, y)

fig, ax = plt.subplots(figsize =(12, 4))
im = ax.imshow(Z, origin = 'lower', extent = [-2, 2, -1, 1])
fig.colorbar(im, shrink = 1)

start = [np.random.uniform(-2, 2), np.random.uniform(-1, 1)]
zero = [0, 0]

ax.scatter(start[0], start[1], color = 'xkcd:red', marker = 'x', label = 'Starting point')


methods = [
    'Nelder-Mead',  # Robust, derivative-free
    'Powell',       # Robust, derivative-free
    'CG',           # Uses numerical gradients
    'BFGS',         # Uses numerical gradients (Standard)
    'L-BFGS-B',     # Uses numerical gradients (Low memory)
    'TNC',          # Uses numerical gradients
    'SLSQP',        # Uses numerical gradients
    'COBYLA'        # Derivative-free (Constrained Optimization BY Linear Approximations)
]

cmap = mpl.colormaps['Set1']

print(enumerate(methods))
for i, method in enumerate(methods):

    sol = sc.optimize.minimize(lambda w: f(w[0], w[1]), start, method = method)
    ax.scatter(sol.x[0], sol.x[1], color = cmap(i), label = method, alpha =0.8)

ax.legend(loc = 'best')

# %% [markdown]
# 4\. **FFT of a simple dataset**
#
# Performe a periodicity analysis on the lynxs-hares population

# %%
from scipy import fftpack as ft

data = np.loadtxt('populations.txt')

years, hares, lynxes, carrots = data.T

h_centered = hares - hares.mean()
l_centered = lynxes - lynxes.mean()

h_sig = ft.fft(h_centered)
h_pow = np.abs(h_sig)
h_freq = ft.fftfreq(h_centered.size)

l_sig = ft.fft(l_centered)
l_pow = np.abs(l_sig)
l_freq = ft.fftfreq(l_centered.size)

plt.figure()
plt.plot(h_freq[h_freq > 0], h_pow[h_freq > 0])
plt.plot(l_freq[l_freq > 0], l_pow[l_freq > 0])
plt.grid()

peak_h = h_freq[h_pow[h_pow > 0].argmax()]
peak_l = l_freq[l_pow[l_pow > 0].argmax()]

high_h = h_sig.copy()
high_h[np.abs(h_freq) > peak_h] = 0
filtered_h = ft.ifft(high_h)

high_l = l_sig.copy()
high_l[np.abs(l_freq) > peak_l] = 0
filtered_l = ft.ifft(high_l)
# Out:
# [  7312.70133873+0.00000000e+00j  20754.75413614-2.42531920e-12j
#   26989.36369132-2.07884503e-12j  24162.97686495+0.00000000e+00j
#   13542.64775974+1.98079122e-12j   -949.59964301-2.10426998e-12j
#  -14120.307888  +0.00000000e+00j -21323.38601366+1.56554324e-12j
#  -20080.85912803+3.24450440e-12j -10941.77616889+0.00000000e+00j
#    2719.01447946-3.23663214e-12j  15891.36587698+9.46101402e-13j
#   23694.31449805+0.00000000e+00j  23099.27201578-8.44062551e-13j
#   14010.68467492-3.53837876e-12j   -673.89500812+0.00000000e+00j
#  -16047.58752243+3.27486033e-12j -26881.99134441+5.01444911e-13j
#  -29434.01363673+0.00000000e+00j -22744.71485504-3.15180889e-13j
#   -8978.96412779+3.02944306e-12j]

# %%
# PLOTTING

fig, ax = plt.subplots()

ax.scatter(years, hares, color = 'xkcd:ocean blue' ,label = 'Hares population')
ax.scatter(years, lynxes, color = 'xkcd:rouge', label ='Lynxes population')

x = np.linspace(years.min(), years.max(), 1000)

ax.plot(years, filtered_h + hares.mean(), color = 'xkcd:ocean blue', label = 'Periodic analysis')
ax.plot(years, filtered_l + lynxes.mean(), color = 'xkcd:rouge', label = 'Periodic analysis')
ax.legend(loc = 'best')
ax.grid()

# %% [markdown]
# 5\. **FFT of an image**
#
# * Examine the provided image `moonlanding.png`, which is heavily contaminated with periodic noise. In this exercise, we aim to clean up the noise using the Fast Fourier Transform.
# * Load the image using pylab.imread().
# * Find and use the 2-D FFT function in scipy.fftpack, and plot the spectrum (Fourier transform of) the image. Do you have any trouble visualising the spectrum? If so, why?
# * The spectrum consists of high and low frequency components. The noise is contained in the high-frequency part of the spectrum, so set some of those components to zero (use array slicing).
# * Apply the inverse Fourier transform to see the resulting image.

# %%
img = plt.imread('moonlanding.png')
plt.imshow(img, cmap = 'grey')

# %%
sig = ft.fft2(img)
sig_shifted = ft.fftshift(sig)                  # SHIFTING IS FUNDAMENTAL BECAUSE IF NOT THE HIGH POWER FREQUENCIES ARE AT THE EDGE
pow = np.log(1 + np.abs(sig_shifted))

rows, cols = img.shape
x_freq = ft.fftfreq(rows)
y_freq = ft.fftfreq(cols)

my_extent = [x_freq.min(), x_freq.max(), y_freq.min(), y_freq.max()]

fig, ax = plt.subplots(figsize = (12, 5))
data = ax.imshow(pow, extent = my_extent)
fig.colorbar(data)

# slicing

p = 0.2

crow = rows // 2
ccol = cols // 2
krow = int(rows * p)
kcol = int(cols * p)

good_signal_shifted = sig_shifted.copy()
good_signal_shifted[:, :] = 0
good_signal_shifted[crow - krow : crow + krow, ccol - kcol : ccol + kcol] = sig_shifted[crow - krow : crow + krow, ccol - kcol : ccol + kcol]
good_signal = ft.ifftshift(good_signal_shifted)

filtered_img = ft.ifft2(good_signal).real

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize = (12, 5))
ax1.imshow(img, cmap = 'grey')
ax2.imshow(filtered_img, cmap = 'grey')
