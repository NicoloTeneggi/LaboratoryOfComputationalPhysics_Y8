# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
from scipy import linalg as la
import matplotlib.pyplot as plt

N = 2000
x1 = np.random.normal(0, 1, (1, N))
x2 = x1 + np.random.normal(0, 3, (1, N))
x3 = 2*x1 + x2

x1.shape
X = np.concatenate((x1, x2, x3), axis =0)
cov = np.cov(X)

l, v = np.linalg.eig(cov)
print('Eigendecomposition: \nEigenvalues:', l, '\nEigenvectors:\n', v)

U, spectrum, V = la.svd(X)          # SVD IS PERFORMED FIRECTLY ON THE DATA MATRIX
v_svd = U
l_svd = spectrum**2 / (N-1)

print('SVD:\n', 'Eigenvalues:', l_svd, '\nEigenvectors:\n', v_svd)


# dimension reduction

Lambda = np.diag(l_svd)
totvar = Lambda.trace()

print('Fraction of variability for each eigenvalue:', l_svd[0]/totvar, l_svd[1]/totvar, l_svd[2]/totvar)

v_svd[:, 2] = 0
print(v_svd)

Xr = np.dot(v_svd.T, X)
Xr.shape
# Out:
# Eigendecomposition:
# Eigenvalues: [ 2.73521993e+01 -1.08032075e-15  1.93598282e+00]
# Eigenvectors:
#  [[-0.11136841 -0.81649658  0.5665072 ]
#  [-0.58245838 -0.40824829 -0.7029051 ]
#  [-0.8051952   0.40824829  0.43010931]]
# SVD:
#  Eigenvalues: [2.73549339e+01 1.93726075e+00 1.43976664e-29]
# Eigenvectors:
#  [[-0.11132675  0.56651539 -0.81649658]
#  [-0.58251007 -0.70286225 -0.40824829]
#  [-0.80516357  0.43016853  0.40824829]]
# Fraction of variability for each eigenvalue: 0.9338642674529343 0.06613573254706574 4.915188685478394e-31
# [[-0.11132675  0.56651539  0.        ]
#  [-0.58251007 -0.70286225  0.        ]
#  [-0.80516357  0.43016853  0.        ]]
# (3, 2000)

# %%
#plotting
fig, ax = plt.subplots(2, 3, figsize = (16, 8), layout = 'tight')
ax[0, 0].scatter(x1, x2, color = 'xkcd:sapphire', alpha = 0.8, s = 10, zorder = 3)
ax[0, 0].grid()
ax[0, 0].set_xlabel('x1')
ax[0, 0].set_ylabel('x2')

ax[0, 1].scatter(x1, x3, color = 'xkcd:sapphire', alpha = 0.8, s = 10, zorder = 3)
ax[0, 1].grid()
ax[0, 1].set_xlabel('x1')
ax[0, 1].set_ylabel('x3')
ax[0, 1].set_title('Original Data')

ax[0, 2].scatter(x2, x3, color = 'xkcd:sapphire', alpha = 0.8, s = 10, zorder =3)
ax[0, 2].grid()
ax[0, 2].set_xlabel('x2')
ax[0, 2].set_ylabel('x3')

ax[1, 0].scatter(Xr[0, :], Xr[1, :], color = 'xkcd:sapphire', alpha = 0.8, s = 10, zorder = 3)
ax[1, 0].grid()
ax[1, 0].set_xlabel('x1')
ax[1, 0].set_ylabel('x2')

ax[1, 1].scatter(Xr[0, :], Xr[2, :], color = 'xkcd:sapphire', alpha = 0.8, s = 10, zorder = 3)
ax[1, 1].grid()
ax[1, 1].set_xlabel('x1')
ax[1, 1].set_ylabel('x3')
ax[1, 1].set_title('Rotated Data')
ax[1, 1].set_ylim(-5, 5)

ax[1, 2].scatter(Xr[1, :], Xr[2, :], color = 'xkcd:sapphire', alpha = 0.8, s = 10, zorder =3)
ax[1, 2].grid()
ax[1, 2].set_xlabel('x2')
ax[1, 2].set_ylabel('x3')
ax[1, 2].set_ylim(-5,5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/

# %%
import pandas as pd
data = pd.read_csv('magic04.data')
data.columns = ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5', 'Feature 6', 'Feature 7', 'Feature 8', 'Feature 9', 'Feature 10', 'g']
X = data.loc[:, ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5', 'Feature 6', 'Feature 7', 'Feature 8', 'Feature 9', 'Feature 10']]
X
# Out:
#        Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0        31.6036    11.7235     2.5185     0.5303     0.3773    26.2722
# 1       162.0520   136.0310     4.0612     0.0374     0.0187   116.7410
# 2        23.8172     9.5728     2.3385     0.6147     0.3922    27.2107
# 3        75.1362    30.9205     3.1611     0.3168     0.1832    -5.5277
# 4        51.6240    21.1502     2.9085     0.2420     0.1340    50.8761
# ...          ...        ...        ...        ...        ...        ...
# 19014    21.3846    10.9170     2.6161     0.5857     0.3934    15.2618
# 19015    28.9452     6.7020     2.2672     0.5351     0.2784    37.0816
# 19016    75.4455    47.5305     3.4483     0.1417     0.0549    -9.3561
# 19017   120.5135    76.9018     3.9939     0.0944     0.0683     5.8043
# 19018   187.1814    53.0014     3.2093     0.2876     0.1539  -167.3125
#
#        Feature 7  Feature 8  Feature 9  Feature 10
# 0        23.8238    -9.9574     6.3609    205.2610
# ...

# %%
U, spectrum, Vt = la.svd(X.T)

l = spectrum**2 / (len(X)-1)
v = U

print('Eigenvalues:', l)

# %%
Lambda = np.diag(l)
total_variance = Lambda.trace()

print('Relative eigenvalue weight:\n', l / total_variance)
print((l / total_variance).cumsum())
# Out:
# Relative eigenvalue weight:
#  [8.41462571e-01 7.40018759e-02 3.67413284e-02 2.35936247e-02
#  1.44777986e-02 7.64364581e-03 2.06859213e-03 9.94201166e-06
#  6.14352022e-07 7.44895960e-09]
# [0.84146257 0.91546445 0.95220577 0.9757994  0.9902772  0.99792084
#  0.99998944 0.99999938 0.99999999 1.        ]
