# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
#1
import pandas as pd
import numpy as np

filename = 'data_000637.txt'

data = pd.read_csv(filename)
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
# [1310720 rows x 6 columns]

# %%
#2
i = data['BX_COUNTER'].max() + 1
j = data['TDC_MEAS'].max() + 1
print('ORBIT_CNT is increased every', i, 'BX_COUNTER')
# Out:
# ORBIT_CNT is increased every 3564 BX_COUNTER

# %%
#3

min1 = data['ORBIT_CNT'].min()
a = data[data['ORBIT_CNT'] == min1]
min2 = a['BX_COUNTER'].min()
b = a[a['BX_COUNTER'] == min2]
min3 = b['TDC_MEAS'].min()

tstart = (min1 * i * 30 + min2 * 30 + min3 * (25/30)) * 1e-9

print('START:', min1, min2, min3, tstart)

max1 = data['ORBIT_CNT'].max()
a = data[data['ORBIT_CNT'] == max1]
max2 = a['BX_COUNTER'].max()
b = a[a['BX_COUNTER'] == max2]
max3 = b['TDC_MEAS'].min()

tstop = (max1 * i * 30 + max2 * 30 + max3 * (25/30)) * 1e-9

print('STOP:', max1, max2, max3, tstop)

x = max1-min1
y = max2 + i - min2
z = max3 + j - min3

t = x * i * 30 + y * 30 + z * 25 / 30
print(f'The measurement lasted {t:.5e} ns or {tstop - tstart :.3f} s ')
# Out:
# START: 3869200167 2374 26 413694.88192688173
# STOP: 3869211171 769 0 413696.05842639005
# The measurement lasted 1.17661e+09 ns or 1.176 s

# %%
#4

data['ABSOLUTE TIME [ns]'] = (data['ORBIT_CNT'] * i * 30 + data['BX_COUNTER'] * 30 + data['TDC_MEAS'] * 25/30)
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          ABSOLUTE TIME [ns]
# 0              4.136949e+14
# 1              4.136949e+14
# 2              4.136949e+14
# 3              4.136949e+14
# ...

# %%
#5
newhead = np.random.randint(0, 2, len(data))
f = data.copy()
f['HEAD'] = newhead
f
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           0     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     0     0           62  3869211171         762        14
# 1310716     0     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          ABSOLUTE TIME [ns]
# 0              4.136949e+14
# 1              4.136949e+14
# 2              4.136949e+14
# 3              4.136949e+14
# ...

# %%
#6

g = f[f['HEAD'] == 1]
g
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# 8           1     0           62  3869200167        2774        21
# ...       ...   ...          ...         ...         ...       ...
# 1310708     1     0          124  3869211171         199         9
# 1310710     1     1           36  3869211171         427        13
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          ABSOLUTE TIME [ns]
# 1              4.136949e+14
# 2              4.136949e+14
# 3              4.136949e+14
# 4              4.136949e+14
# ...

# %%
#7
import matplotlib.pyplot as plt
zero = data[data['FPGA'] == 0]
one = data[data['FPGA'] == 1]
a = zero.groupby('TDC_CHANNEL').size()
b = one.groupby('TDC_CHANNEL').size()

fig, [ax1, ax2] = plt.subplots(1, 2, figsize = (13, 5))
a.plot(kind = 'bar', ax = ax1, title = 'FPGA 0')

ticks_to_show = np.arange(0, len(a)+1, 7)
ax1.set_xticks(ticks_to_show)
ax1.set_xticklabels(a.index[ticks_to_show])

b.plot(kind = 'bar', ax = ax2, title = 'FPGA 1')
ticks_to_show = np.arange(0, len(b)+1, 7)
ax2.set_xticks(ticks_to_show)
ax2.set_xticklabels(b.index[ticks_to_show])
# Out:
# [Text(0, 0, '1'),
#  Text(7, 0, '8'),
#  Text(14, 0, '15'),
#  Text(21, 0, '22'),
#  Text(28, 0, '29'),
#  Text(35, 0, '36'),
#  Text(42, 0, '43'),
#  Text(49, 0, '50'),
#  Text(56, 0, '57'),
#  Text(63, 0, '64'),
#  Text(70, 0, '71'),
#  Text(77, 0, '78'),
#  Text(84, 0, '85'),
#  Text(91, 0, '92'),
#  Text(98, 0, '99'),
#  Text(105, 0, '106'),
#  Text(112, 0, '113'),
#  Text(119, 0, '120'),
#  Text(126, 0, '128')]

# %%
#8

a_sorted = a.sort_values()
print(a_sorted.tail(3))

b_sorted = b.sort_values()
print(b_sorted.tail(3))
# Out:
# TDC_CHANNEL
# 63     63724
# 64     64581
# 139    75617
# dtype: int64
# TDC_CHANNEL
# 1      28438
# 139    32442
# 2      32669
# dtype: int64

# %%
#9

unique_values = data['ORBIT_CNT'].unique()
print(len(unique_values))

n = data[data['TDC_CHANNEL'] == 139]
gg = n['ORBIT_CNT'].unique()
print(len(gg))
# Out:
# 11001
# 10976
