# %% [markdown]
# The following exercises are meant to be solved by gathering the bash commands incrimentally in two scripts, one for ex 1.* the other for ex 2.*

# %% [markdown]
# ### Ex 1

# %% [markdown]
# 1\.a Make a new directory called `students` in your home. Download a csv file with the list of students of this lab from [here](https://www.dropbox.com/s/867rtx3az6e9gm8/LCP_22-23_students.csv) (use the `wget` command) and copy that to `students`. First check whether the file is already there

# %% [markdown]
# 1\.b Make two new files, one containing the students belonging to PoD, the other to Physics.

# %% [markdown]
# 1\.c For each letter of the alphabet, count the number of students whose surname starts with that letter.

# %% [markdown]
# 1\.d Find out which is the letter with most counts.

# %% [markdown]
# 1\.e Assume an obvious numbering of the students in the file (first line is 1, second line is 2, etc.), group students "modulo 18", i.e. 1,19,37,.. 2,20,38,.. etc. and put each group in a separate file

# %%
wget FileLink

if [ ! -f "./students.csv" ]; then echo "the file ./students.csv does not exist!"; else echo "The file is present" fi;
    
touch students_ph.csv
grep 'Physics' students.csv > students_ph.csv
touch students_PoD.csv
grep 'PoD' students.csv > students_PoD.csv

maximum=0
letter=0
for l in {A..Z}; do a=$(grep -c "^$l" students.csv); if [ $a -gt $maximum ]; then maximum=$a; letter=$l; fi; done
    
for i in {2..19}; do touch group_$i.csv; counter=$i; while [ $counter -lt 73 ]; do cut -f $counter -d $'\n' students.csv >> group_$i.csv; let counter+=18; done; done

# %% [markdown]
# ### Ex 2

# %% [markdown]
# 2.a Make a copy of the file `data.csv` removing the metadata and the commas between numbers; call it `data.txt`

# %% [markdown]
# 2\.b How many even numbers are there?

# %% [markdown]
# 2\.c Distinguish the entries on the basis of `sqrt(X^2 + Y^2 + Z^2)` is greater or smaller than `100*sqrt(3)/2`. Count the entries of each of the two groups

# %% [markdown]
# 2\.d Make `n` copies of data.txt (with `n` an input parameter of the script), where the i-th copy has all the numbers divided by i (with `1<=i<=n`).

# %%
touch data.txt
sed "s/,//g" data.csv | grep -v "^#" data.txt

for i in {1..50}; do for j in {1..6}; do a=$(cut -f $i -d $'\n' data.txt | cut -f $j -d ' '); if (( $a%2==0 )); then let counter+=1; fi; done; done; echo There are $counter even numbers in the file

G=0; S=0; for i in {1..50}; do x1=0; x2=0; x3=0; x1=$(cut -f $i -d $'\n' data.txt | cut -f1
-d ' '); x2=$(cut -f $i -d $'\n' data.txt | cut -f2 -d ' '); x3=$(cut -f $i -d $'\n' data.txt | cut -f3 -d ' '); d=$(ech
o "scale=5;sqrt($x1^2+$x2^2+$x3^2)" |bc) ; if (( $(echo "$d > $limit" | bc) )); then let G+=1; else let S+=1; fi; done;
echo G = $G, S = $S

read -p "Enter the value of n: " n; counter=1; while [ $counter -le $n ]; do touch copy_$counter.csv; for i in {1..50}; do for j in {1..6}; do a=$(cut -f $i -d $'\n' data.txt | cut -f $j -d ' '); extra=$(echo "scale=2; $a / $counter" | bc); echo -n "$extra " >> copy_$counter.csv; done;echo '' >> copy_$counter.csv; done; let counter+=1; done
