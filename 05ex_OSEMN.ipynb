# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
output = np.random.randint(1, 100, size=(1, 100))
print(output)

np.savetxt("simple_data.txt", output, fmt = "%d")
# Out:
# [[ 6  3 92 13 37 25 47 13 12 62 35 23 11 25 61 86 58 75 86 20 14 41 84 23
#   35 27 41 71 94 41 65 27 29 61 68 33 38 99 19 58 89 28  7 32 55 66 28 16
#   63 60  1 55 61 40 56 46  3 93  6 71 81 81 35 82 37 47 51 25 26 58 27 64
#   86 15 88 65 82 68  9 82 46 77 42 75 82 76 74 83 33  8 88 54 43 23 73 73
#   79 93 37 35]]

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
output = np.random.randint(0, 100, size=(5, 5))
print(output)

np.savetxt("data.txt", output, fmt = '%d')
# Out:
# [[68 24 98 15 65]
#  [21 31 23 73 59]
#  [13 63 98 33 58]
#  [70 95  5 24 22]
#  [12 18 28 23 83]]

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
with open("./data.txt", "r") as data: 
    with open("./data.csv", "w") as data_csv:
        writer = csv.writer(data_csv, delimiter = ",")

        for line in data:
            print(line.strip().split())

            writer.writerow(line.strip().split())
# Out:
# ['68', '24', '98', '15', '65']
# ['21', '31', '23', '73', '59']
# ['13', '63', '98', '33', '58']
# ['70', '95', '5', '24', '22']
# ['12', '18', '28', '23', '83']

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with open("credit_card.dat", 'rb') as file:
    word_size = 6
    for line in file:
            for i in range(0, len(line), word_size):
                print(chr(int(line[i:i+word_size], 2)), end = '')
# Out:
# 7648 5673 3775 2271
# 3257 8247 3354 2266
# 2722 0001 4011 6652
# 0661 3063 3742 3150
# 0432 1608 1462 4742
# 5827 2027 8785 7303
# 5774 8528 2087 1117
# 8140 1210 6352 2845
# 5764 1133 7301 7100
# 6456 1737 4126 6726
# 1228 8631 7382 0000
# 7051 0160 5374 3166
# 0618 3587 1630 6376
# 1545 5454 7444 5636
# 6735 3116 3202 6834
# 7287 5011 1547 8413
# 7033 2607 3328 4200
# 2568 5244 1874 5024
# 1684 2253 7570 7118
# 0672 2576 0575 6631
# 6332 8353 8787 1340
# 1813 3361 1175 4211
# 2477 6450 8840 2368
# 5512 3505 2563 1326
# 3083 7882 0621 0025
# 4521 5148 8045 0334
# 7563 3654 8713 5787
# 8324 2664 0476 5561
# 0565 2504 7168 3510
# 5107 5507 1767 0738
# 2462 1821 2448 1443
# 2788 0638 6861 6554
# 5851 5873 5474 0547
# 0670 1004 4013 2655
# 5874 5506 3048 0806
# 2805 5401 8462 1260
# 5083 8406 6310 1862
# 1076 1445 3013 2266
# 8440 4804 4844 5277
# 4758 6141 0686 1387
# 7586 0675 0315 2568
# 2544 1258 7432 5165
# 3474 5023 4434 5626
# 1410 0270 0434 5086
# 7315 4446 1104 4215
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json

user_data = json.load(open('user_data.json'))
dict_keys = user_data[1].keys()
print(dict_keys, type(dict_keys))

for i in user_data:
    if i['CreditCardType'] == 'American Express':
        print(i.values())

with open('user_data.csv', 'w') as out:
    writer = csv.writer(out, delimiter = ",")
    writer.writerow(dict_keys)
    for i in user_data:
        if i['CreditCardType'] == 'American Express':
            writer.writerow(i.values())
# Out:
# dict_keys(['ID', 'JobTitle', 'EmailAddress', 'FirstNameLastName', 'CreditCard', 'CreditCardType']) <class 'dict_keys'>
# dict_values(['2', 'Investment  Advisor', 'Clint_Thorpe5003@bulaffy.com', 'Clint Thorpe', '7083-8766-0251-2345', 'American Express'])
# dict_values(['12', 'Retail Trainee', 'Phillip_Carpenter9505@famism.biz', 'Phillip Carpenter', '3657-0088-0820-5247', 'American Express'])
# dict_values(['28', 'Project Manager', 'Russel_Graves1378@extex.org', 'Russel Graves', '6718-4818-8011-6024', 'American Express'])
# dict_values(['39', 'Stockbroker', 'Leanne_Newton1268@typill.biz', 'Leanne Newton', '5438-0816-4166-4847', 'American Express'])
# dict_values(['57', 'Budget Analyst', 'Tony_Giles1960@iatim.tech', 'Tony Giles', '8130-3425-7573-7745', 'American Express'])
# dict_values(['62', 'CNC Operator', 'Owen_Allcott5125@bauros.biz', 'Owen Allcott', '4156-0107-7210-2630', 'American Express'])
# ...

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
filename = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
data = pd.read_csv(filename)
data['class'].plot(kind ='hist')
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
filename = 'https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'

data = pd.read_csv(filename)
data
# Out:
#            label  features_1  features_2  features_3  features_4  features_5  \
# 0     -89.243497    2.175170   -0.285786   -0.603396   -0.627453   -0.686474
# 1     230.050125    1.481941   -1.327870   -0.543583   -0.303578    1.552964
# 2    -286.844411   -1.154394   -0.178649   -1.636646    0.239353   -0.684994
# 3     364.552862    0.197665    1.455707    1.562205    2.168207    0.053335
# 4     515.460006    0.596676    0.969860    1.294158   -0.404728    2.145297
# ...          ...         ...         ...         ...         ...         ...
# 1995 -328.100239   -1.820929    1.358539   -2.494838    0.828299    0.199255
# 1996  -62.960036   -0.883712   -0.063687   -0.418704   -0.872601    0.363769
# 1997  -90.262252   -0.021394   -0.312864   -0.730848   -1.341482   -0.720862
# 1998  -74.333901   -0.041909   -0.862731   -1.232011    1.268843    0.093043
# 1999    8.321454   -1.056364    0.259247    0.307835    1.094903    0.472395
#
# ...

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.
